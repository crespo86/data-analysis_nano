# %%
library(ggplot2)
# Out:
# Warning message:
# : package ‘ggplot2’ was built under R version 3.2.3

# %%
ggplot(data = mpg,
       mapping = aes(x = cty, y = hwy)) + 
    geom_point()
# Out:
# plot without title

# %%
ggplot(data = mpg,
       mapping = aes(x = cty, y = hwy)) + 
    geom_count()
# Out:
# plot without title

# %%
d <- ggplot(data = diamonds,
            mapping = aes(x = cut, y = clarity))
d + geom_count(mapping = aes(size = ..prop..))
# Out:
# plot without title

# %%
d + geom_count(mapping = aes(size = ..prop.., group = 1)) + 
    scale_size_area(max_size = 10)
# Out:
# plot without title

# %%
d + geom_count(mapping = aes(size = ..prop.., group = cut)) +
    scale_size_area(max_size = 10)
# Out:
# plot without title

# %%
d + geom_count(mapping = aes(size = ..prop.., group = clarity)) +
    scale_size_area(max_size = 10)
# Out:
# plot without title
