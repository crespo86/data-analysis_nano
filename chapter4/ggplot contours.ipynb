# %%
library(ggplot2)

# %%
faithfuld
# Out:
#             eruptions waiting              density
# 1                 1.6      43  0.00321615883393854
# 2     1.6472972972973      43   0.0038353752391414
# 3    1.69459459459459      43  0.00443554776590651
# 4    1.74189189189189      43  0.00497761392700709
# 5    1.78918918918919      43  0.00542423752549007
# 6    1.83648648648649      43  0.00574454417323502
# 7    1.88378378378378      43  0.00591801178663078
# 8    1.93108108108108      43  0.00593676162515817
# 9    1.97837837837838      43  0.00580586069937781
# 10   2.02567567567568      43  0.00554170622763238
# 11   2.07297297297297      43  0.00516897871574589
# 12   2.12027027027027      43  0.00471690329219113
# 13   2.16756756756757      43  0.00421559183089581
# 14   2.21486486486487      43  0.00369307111905593
# 15   2.26216216216216      43  0.00317331672803034
# 16   2.30945945945946      43  0.00267531454027745
# 17   2.35675675675676      43  0.00221295109503029
# ...

# %%
v <- ggplot(data = faithfuld,
            mapping = aes(x = waiting, y = eruptions, z = density))
v + geom_contour()
# Out:
# plot without title

# %%
v + geom_contour(bins = 2)
# Out:
# plot without title

# %%
v + geom_contour(bins = 10)
# Out:
# plot without title

# %%
v + geom_contour(binwidth = 0.001)
# Out:
# plot without title

# %%
v + geom_contour(mapping = aes(colour = ..level..))
# Out:
# plot without title

# %%
v + geom_contour(colour= 'red')
# Out:
# plot without title

# %%
v + geom_raster(mapping = aes(fill = density)) + geom_contour(colour = 'white')
# Out:
# plot without title
